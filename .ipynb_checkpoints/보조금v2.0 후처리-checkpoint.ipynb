# %%
import time
import pyperclip
import pandas as pd
from pyautogui import *

# %%
pos = locateCenterOnScreen("deregistrated.png", grayscale=True)
pos = Point(x=pos.x+190, y=pos.y+120)
moveTo(pos)

# %%
car_list = pd.read_excel("보조금입력(5월).xlsx", dtype="string")

# %%
car_list = car_list[['차량번호', '특기사항']]

# %%
len(car_list)
# Out:
# 84

# %%
car_list
# Out:
#          차량번호                                               특기사항
# 0     33다8583  서울특별시, 전기차 구매보조금 379만원(국비 332만원, 시비 47만원, 지급일자...
# 1     22우5588  서울특별시, 전기차 구매보조금 900만원(국비 700만원, 시비 200만원, 지급일...
# 2     15고8435  서울특별시, 전기차 구매보조금 900만원(국비 700만원, 시비 200만원, 지급일...
# 3     20도8332  서울특별시, 전기차 구매보조금 339만원(국비 264만원, 시비 75만원, 지급일자...
# 4     50서3275  서울특별시, 전기차 구매보조금 437만원(국비 340만원, 시비 97만원, 지급일자...
# ..        ...                                                ...
# 79  서울75사1392  서울특별시, 전기차 구매보조금 16,000만원(국비 8,000만원, 시비 8000만...
# 80  서울74사8778  서울특별시, 전기차 구매보조금 16,000만원(국비 8,000만원, 시비 8000만...
# 81  서울74사3610  서울특별시, 전기차 구매보조금 16,000만원(국비 8,000만원, 시비 8000만...
# 82    71오7369  서울특별시, 전기차 구매보조금 9,874만원(국비 4,887만원, 시비 4987만원...
# 83    27로6513  서울특별시, 전기차 구매보조금 3,250만원(국비 2,250만원, 시비 1000만원...
#
# [84 rows x 2 columns]

# %% [markdown]
# ### 1. 보조금 ==> 특기사항 입력

# %%
for i in range(0, len(car_list)):
    
    regnum = car_list['차량번호'][i]
    memo = car_list['특기사항'][i]
    
    # 초기화
    pos = locateCenterOnScreen("init.png", grayscale=True)
    while pos is None:
        print(f"[오류] 초기화 버튼 찾기 ==> 현재 index={i}")
        time.sleep(1)
        pos = locateCenterOnScreen("init.png", grayscale=True)
    moveTo(pos)
    click()
    time.sleep(1)
    
    # 등록번호 입력
    pos = locateCenterOnScreen("regnum.png", grayscale=True)
    while pos is None:
        print(f"[오류] 등록번호 입력칸 찾기 ==> 현재 index={i}")
        time.sleep(1)
        pos = locateCenterOnScreen("regnum.png", grayscale=True)
#     moveTo(pos)
#     moveRel(100, 0)
    pos = Point(x=pos.x+100, y=pos.y)
    moveTo(pos)
    click()
    pyperclip.copy(regnum)
    hotkey('ctrl', 'v')
    
    # 조회 클릭
    pos = locateCenterOnScreen("search.png", grayscale=True)
    while pos is None:
        print(f"[오류] 조회 버튼 찾기 ==> 현재 index={i}")
        time.sleep(1)
        pos = locateCenterOnScreen("search.png", grayscale=True)
    moveTo(pos)
    click()
    time.sleep(1)
    
    # 특기사항 입력
    pos = locateCenterOnScreen("memo.png", grayscale=True)
    while pos is None:
        print(f"[오류] 특기사항 입력칸 찾기 ==> 현재 index={i}")
        time.sleep(1)
        pos = locateCenterOnScreen("memo.png", grayscale=True)
#     moveTo(pos)
#     moveRel(0, 50)
    pos = Point(x=pos.x, y=pos.y+50)
    moveTo(pos)
    click()
    pyperclip.copy(memo)
    hotkey('ctrl', 'v')
    
    # 저장 클릭
    pos = locateCenterOnScreen("save.png", grayscale=True)
    while pos is None:
        print(f"[오류] 저장 버튼 찾기 ==> 현재 index={i}")
        time.sleep(1)
        pos = locateCenterOnScreen("save.png")
    moveTo(pos)
    click()
    time.sleep(1)
    
    # 저장 완료되었습니다. "확인" 클릭
    pos = locateCenterOnScreen("complete.png")
    while pos is None:
        print(f"[오류] 저장 완료 후 확인 버튼 찾기 ==> 현재 index={i}")
        time.sleep(1)
        pos = locateCenterOnScreen("complete.png")
#     moveTo(pos)
#     moveRel(170, 120)
    pos = Point(x=pos.x+170, y=pos.y+120)
    moveTo(pos)
    click()
    time.sleep(1)

# %% [markdown]
# ### 2. 특기사항 추출 ==> 엑셀 파일 내용과 비교 및 검증

# %%
for i in range(len(car_list)):
    
    regnum = car_list['차량번호'][i]
    memo = car_list['특기사항'][i]
    
    # 초기화
    pos = locateCenterOnScreen("init.png")
    while pos is None:
        print(f"[오류] 초기화 버튼 찾기 ==> 현재 index={i}")
        time.sleep(0.5)
        pos = locateCenterOnScreen("init.png")
    moveTo(pos)
    click()
    time.sleep(0.5)
    
    # 등록번호 입력
    pos = locateCenterOnScreen("regnum.png")
    while pos is None:
        print(f"[오류] 등록번호 입력칸 찾기 ==> 현재 index={i}")
        time.sleep(0.5)
        pos = locateCenterOnScreen("regnum.png")
#     moveTo(pos)
#     moveRel(100, 0)
    pos = Point(x=pos.x+100, y=pos.y)
    moveTo(pos)
    click()
    pyperclip.copy(regnum)
    hotkey('ctrl', 'v')
    
    # 조회 클릭
    pos = locateCenterOnScreen("search.png")
    while pos is None:
        print(f"[오류] 조회 버튼 찾기 ==> 현재 index={i}")
        time.sleep(0.5)
        pos = locateCenterOnScreen("search.png")
    moveTo(pos)
    click()
    time.sleep(0.5)
    
    # 오늘 입력한 특기사항 추출
    pos = locateCenterOnScreen("list_item.png", grayscale=True)
    while pos is None:
        print(f"[오류] 오늘 금방 입력한 특기사항 리스트 아이템  ==> 현재 index={i}")
        time.sleep(0.5)
        pos = locateCenterOnScreen("list_item.png")
    moveTo(pos)
    doubleClick()

    pos = locateCenterOnScreen("memo.png")
    while pos is None:
        print(f"[오류] 특기사항 입력칸 찾기 ==> 현재 index={i}")
        time.sleep(0.5)
        pos = locateCenterOnScreen("memo.png")
#     moveTo(pos)
#     moveRel(0, 50)
    pos = Point(x=pos.x, y=pos.y+50)
    moveTo(pos)
    click()
    hotkey('ctrl', 'a')
    hotkey('ctrl', 'c')

    contents = pyperclip.paste()
    if contents == memo:
        print(f"[확인 {(i+1):>2}/{len(car_list):>3}] 등록번호: {regnum} \t =====> 특기사항 입력 확인 OK")
    else:
        print(f"[확인 {(i+1):>2}/{len(car_list):>3}] 등록번호: {regnum} \t =====> 특기사항 입력 오류 ㅠㅠ")    
    time.sleep(1)
	
print("특기사항 입력 확인 끝!!")
# Out:
# [확인  1/ 84] 등록번호: 33다8583 	 =====> 특기사항 입력 확인 OK
# [확인  2/ 84] 등록번호: 22우5588 	 =====> 특기사항 입력 확인 OK
# [확인  3/ 84] 등록번호: 15고8435 	 =====> 특기사항 입력 확인 OK
# [확인  4/ 84] 등록번호: 20도8332 	 =====> 특기사항 입력 확인 OK
# [확인  5/ 84] 등록번호: 50서3275 	 =====> 특기사항 입력 확인 OK
# [확인  6/ 84] 등록번호: 54버1098 	 =====> 특기사항 입력 확인 OK
# [확인  7/ 84] 등록번호: 54머0263 	 =====> 특기사항 입력 확인 OK
# [확인  8/ 84] 등록번호: 48나7630 	 =====> 특기사항 입력 확인 OK
# [확인  9/ 84] 등록번호: 03조1616 	 =====> 특기사항 입력 확인 OK
# [확인 10/ 84] 등록번호: 54로4795 	 =====> 특기사항 입력 확인 OK
# [확인 11/ 84] 등록번호: 60버8676 	 =====> 특기사항 입력 확인 OK
# [확인 12/ 84] 등록번호: 58루7659 	 =====> 특기사항 입력 확인 OK
